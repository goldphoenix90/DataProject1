# %%
import pandas as pd
import numpy as np

file1 = "ACS_17_5YR_B23006_with_ann.csv"

# %%
ACS = pd.read_csv(file1, encoding="ISO-8859-1")
ACS.head()
# Out:
#            GEO.id GEO.id2       GEO.display-label         HD01_VD01  \
# 0              Id     Id2               Geography  Estimate; Total:
# 1  310M300US10180   10180  Abilene, TX Metro Area             81933
# 2  310M300US10420   10420    Akron, OH Metro Area            366649
# 3  310M300US10500   10500   Albany, GA Metro Area             77662
# 4  310M300US10540   10540   Albany, OR Metro Area             62045
#
#                  HD02_VD01                                  HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Less than high school graduate:
# 1                      211                                      10436
# 2                      186                                      25835
# 3                      258                                      11358
# 4                      304                                       5567
#
#                                           HD02_VD02  \
# 0  Margin of Error; Less than high school graduate:
# ...

# %%
ACS
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-035fcd505cf6> in <module>
# ----> 1 ACS[0,:]
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# ...
