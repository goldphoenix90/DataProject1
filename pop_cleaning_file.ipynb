# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

# %%
# reading the CSV file from Zillow on rental data for metros
file = 'PEP_2018_PEPANNRSIP.US12A_with_ann.csv'
population = pd.read_csv(file, encoding="ISO-8859-1")
#checking the columns
population.head()
# Out:
#       GEO.id GEO.id2 GEO.display-label GC_RANK.target-geo-id  \
# 0         Id     Id2         Geography         Target Geo Id
# 1  0100000US     NaN     United States      1620000US3651000
# 2  0100000US     NaN     United States      1620000US0644000
# 3  0100000US     NaN     United States      1620000US1714000
# 4  0100000US     NaN     United States      1620000US4835000
#
#   GC_RANK.target-geo-id2 GC_RANK.rank-label  \
# 0         Target Geo Id2               Rank
# 1                3651000                  1
# 2                0644000                  2
# 3                1714000                  3
# 4                4835000                  4
#
#                           GC_RANK.display-label       GC_RANK.display-label.1  \
# 0                                     Geography                     Geography
# 1       United States - New York city, New York       New York city, New York
# 2  United States - Los Angeles city, California  Los Angeles city, California
# ...

# %%
population_r = population.rename(columns={
    "GC_RANK.display-label.1": "RegionName",
    "rescensus42010": "Pop 2010",
    "respop72018": "Pop 2018"
})
population_r["RegionName"].count()
# Out:
# 781

# %%
population_r["RegionName"] = population_r["RegionName"].str.replace(' city', '', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(' ,', ',', regex=True)

population_r["RegionName"] = population_r["RegionName"].str.replace(', New York', ', NY', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', California', ', CA', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Illinois', ', IL', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Texas', ', TX', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Arizona', ', AZ', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Pennsylvania', ', PA', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Florida', ', FL', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Ohio', ', OH', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', North Carolina', ', NC', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace('(balance)', '', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Indiana', ', IN', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Washington', ', WA', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Colorado', ', CO', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', District of Columbia', ', DC', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Massachusetts', ', MA', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Michigan', ', MI', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Tennessee', ', TN', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Oklahoma', ', OK', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Nevada', ', NV', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Kentucky', ', KY', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Oregon', ', OR', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Maryland', ', MD', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Wisconsin', ', WI', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', New Mexico', ', NM', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Georgia', ', GA', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Missouri', ', MO', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Nebraska', ', NE', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Virginia', ', VA', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Minnesota', ', MN', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Louisiana', ', LA', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Kansas', ', KS', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Hawaii', ', HI', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Alaska', ', AK', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', New Jersey', ', NJ', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Indiana', ', IN', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Idaho', ', ID', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Iowa', ', IA', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Alabama', ', AL', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Utah', ', UT', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Arkansas', ', AR', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', South Dakota', ', SD', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Rhode Island', ', RI', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Mississippi', ', MS', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Connecticut', ', CT', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', South Carolina', ', SC', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', North Dakota', ', ND', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', New Hampshire', ', NH', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Montana', ', MT', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Connecticut', ', CT', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Delaware', ', DE', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', Wyoming', ', WY', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(', West Virginia', ', WV', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace('Los Angeles', 'Los Angeles-Long Beach-Anaheim', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(' metropolitan', '', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace('Dallas', 'Dallas-Fort Worth', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace('Miami', 'Miami-Fort Lauderdale', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace('Minneapolis', 'Minneapolis-St Paul', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(' metro', '', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(' government', '', regex=True)
population_r["RegionName"] = population_r["RegionName"].str.replace(r"\(.*\)","")
population_r["RegionName"] = population_r["RegionName"].str.replace(" ,",",")
population_r["RegionName"] = population_r["RegionName"].str.replace("/","-")
population_r["RegionName"] = population_r["RegionName"].str.replace("CDP","")
population_r["RegionName"] = population_r["RegionName"].str.replace("Nashville-Davidson","Nashville")
population_r["RegionName"] = population_r["RegionName"].str.replace("urban","")
population_r["RegionName"] = population_r["RegionName"].str.replace("Augusta-Richmond County","Augusta")
population_r["RegionName"] = population_r["RegionName"].str.replace("town","")
population_r["RegionName"].head()
# Out:
# 0                             Geography
# 1                          New York, NY
# 2    Los Angeles-Long Beach-Anaheim, CA
# 3                           Chicago, IL
# 4                           Houston, TX
# Name: RegionName, dtype: object

# %%
population_r["Pop 2010"] = population_r["Pop 2010"].str.replace(r"\(.*\)","")

# %%
population_r = population_r.dropna(how = "any")

# %%
population_r.to_csv("Population_census2.csv", index = False)
